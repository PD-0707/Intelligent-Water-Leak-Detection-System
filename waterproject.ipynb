# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Create dataset manually
data = pd.DataFrame([
[339.27,461,1026.58,1235.4,0],
[305.63,465,2322.25,1413.02,0],
[270.23,363,1505.69,1109.19,0],
[334.94,435,1295.8,598.14,0],
[229.38,336,1271.71,1027.06,0],
[295.39,400,477.93,620.36,0],
[277.51,364,1366.74,688.38,0],
[331.03,584,4674.84,1613.33,0],
[196.12,325,907.15,1503.98,0],
[162.11,287,3547.88,919.48,0],
[115.57,240,3025.95,1243.83,0],
[110,275,5850.56,877.35,0],
[956.52,1330,131312.02,1148.11,1],
[747.08,1148,24387.14,1445.38,1],
[129.28,385,11900.43,294.91,0],
[948.88,1337,69070.94,756.45,1],
[1094.73,1385,50631.13,884.74,1],
[1183.43,1331,4885.04,1282.39,1],
[819.92,1317,42347.94,4650.78,1],
[625.03,883,10537.33,1089.73,1],
[802.02,1213,6702.15,2528.86,1],
[708.63,920,3433.64,1209.84,1],
[449.97,647,3590.61,680.28,1],
[528.89,656,2118.61,1296.13,1],
[376.97,569,8915.51,1913.09,1],
[303.89,441,2813.58,924,0],
[342.75,528,5138.37,1857.15,0],
[584.85,787,12097,1240.42,1],
[645.67,833,5102.45,3956.89,1],
[529.74,681,3466.18,722.43,1]
], columns=['RMS','Peak','Variance','FreqEnergy','Label'])

X = data[['RMS','Peak','Variance','FreqEnergy']]
y = data['Label']

# Normalize
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(8, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=80)

# Evaluate
loss, acc = model.evaluate(X_test, y_test)
print("Accuracy:", acc)
# Out:
# Epoch 1/80
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5417 - loss: 0.7794
# Epoch 2/80
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5417 - loss: 0.7744
# Epoch 3/80
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5417 - loss: 0.7694
# Epoch 4/80
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5417 - loss: 0.7644
# Epoch 5/80
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5417 - loss: 0.7594
# Epoch 6/80
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5417 - loss: 0.7544
# Epoch 7/80
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5417 - loss: 0.7494
# Epoch 8/80
# ...

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

open("model.tflite", "wb").write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpocsk7iaz'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 4), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   134464619087440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134464619088592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134464619087248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134464619085904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134464619089168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134464619086096: TensorSpec(shape=(), dtype=tf.resource, name=None)
# 2464

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

open("model.tflite", "wb").write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmp1e9v9lc_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 4), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   134464619087440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134464619088592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134464619087248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134464619085904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134464619089168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134464619086096: TensorSpec(shape=(), dtype=tf.resource, name=None)
# 2464

# %%
# Convert to C array
with open("model.tflite", "rb") as f:
    model = f.read()

with open("model.h", "w") as f:
    f.write("const unsigned char model[] = {")
    f.write(",".join(str(b) for b in model))
    f.write("};")
